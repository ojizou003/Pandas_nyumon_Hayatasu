# %%
# !pip install open-interpreter
import interpreter
interpreter.api_key = "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"
interpreter.auto_run = True
interpreter.chat()
# Out:
# ...
#   Obtaining dependency information for open-interpreter from https://files.pythonhosted.org/packages/49/c0/cbb2ffc6ab776d1dbbb966458714f789f314d62542541d30b279e22e9dde/open_interpreter-0.1.7-py3-none-any.whl.metadata
#   Using cached open_interpreter-0.1.7-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# ...
#   Using cached astor-0.8.1-py2.py3-none-any.whl (27 kB)
# ...
#   Using cached git_python-1.0.3-py2.py3-none-any.whl (1.9 kB)
# ...
#   Obtaining dependency information for huggingface-hub<0.17.0,>=0.16.4 from https://files.pythonhosted.org/packages/7f/c4/adcbe9a696c135578cabcbdd7331332daad4d49b7c43688bc2d36b3a47d2/huggingface_hub-0.16.4-py3-none-any.whl.metadata
#   Using cached huggingface_hub-0.16.4-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached inquirer-3.1.3-py3-none-any.whl (18 kB)
# ...
